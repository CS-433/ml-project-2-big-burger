# %%
# Hyperparameters for simulation
nparticles = 1000   # Number of particles
nframes = 10    # Number of steps in the simulation
nposframe = 10    # Number of position per frame
dt = 0.01        # Integration time frame in second (time between two frames)
DGen = 10000        # Diffusion coefficient in nm^2 per s (=0.001 (um^2)/s)
num_steps = nframes*nposframe
# Hyperparameters for image generation
npixel = 64 # number of image pixels
pixelsize = 100 # in nm 
fwhm_psf = 200 # full width half maximum (emulates microscope)
factor_hr = 5 # image high resulution factor
flux = 100 # number of photons per s
poisson_noise = 100 
gaussian_noise = 10
background = 100 # base background value
normalizeValue = 1000 # value by which all samples will be normalized ! Needs to be fixed and the same for all images !
n_val_im = 50

# %%
# %reload_ext autoreload
# %autoreload 2
from helpers import *
from modelsUtils import *
from simpleCNNModel import *
from ResNetModel import *
from paperCNN import *
import os.path

device = torch.device("mps" if torch.backends.mps.is_available() else "cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: mps

# %%
def compute_centroid_positions(trajectory, nframes, nposframe):
    """
    Computes the centroid positions for each frame in the trajectory.
    
    Parameters:
    - trajectory (ndarray): Array of shape (num_steps, 2), positions over time.
    - nframes (int): Number of frames.
    - nposframe (int): Number of positions per frame.
    
    Returns:
    - centroids (ndarray): Array of shape (nframes, 2), centroid positions for each frame.
    """
    centroids = np.zeros((nframes, 2))
    for k in range(nframes):
        start = k * nposframe
        end = (k + 1) * nposframe
        segment = trajectory[start:end, :]
        centroid = np.mean(segment, axis=0)
        centroids[k, :] = centroid
    return centroids

def mean_square_displacement_from_centroids(centroids):
    """
    Computes the MSD from centroid positions over frames.
    
    Parameters:
    - centroids (ndarray): Array of shape (nframes, 2)
    
    Returns:
    - msd (ndarray): MSD values for time lags.
    """
    nframes = centroids.shape[0]
    msd = np.zeros(nframes)
    for tao in range(1, nframes):  # start from tao=1
        displacements = np.sum((centroids[tao:] - centroids[:nframes-tao])**2, axis=1)
        msd[tao] = np.mean(displacements)
    return msd

def estimateDfromCentroids(trajectory, nframes, nposframe, dt):
    centroids = compute_centroid_positions(trajectory, nframes, nposframe)
    centroids_time = np.arange(nframes) * dt  # time points for centroids
    msd = mean_square_displacement_from_centroids(centroids)
    D_coarse = estimateDfromMSD(msd, centroids_time)
    return D_coarse

# %%
def generateImagesAndEstimateDFromTrajs(
    trajectories, nparticles, nframes, npixel, factor_hr, nposframe, D, dt,
    fwhm_psf, pixelsize, flux, background, poisson_noise, gaussian_noise, normalizeValue=-1):
    """
    Generates images and estimates both fine and coarse diffusion coefficients (D) for each particle.
    
    Parameters:
    - trajectories (ndarray): Array of shape (nparticles, num_steps, 2)
    - Other parameters as before
    
    Returns:
    - image_array (ndarray): Array of shape (nparticles, nframes, npixel, npixel)
    - D_estimates (ndarray): Array of size (nparticles), estimated D from full trajectory
    - D_estimates_coarse (ndarray): Array of size (nparticles), estimated D from centroids
    """
    image_array = np.zeros((nparticles, nframes, npixel, npixel))
    D_estimates = np.zeros(nparticles)
    D_estimates_coarse = np.zeros(nparticles)
    time_range = np.arange(nframes * nposframe) * dt / nposframe

    for p in range(nparticles):
        trajectory = trajectories[p]
        frame_hr = np.zeros((nframes, npixel * factor_hr, npixel * factor_hr))
        frame_noisy = np.zeros((nframes, npixel, npixel))

        for k in range(nframes):
            start = k * nposframe
            end = (k + 1) * nposframe
            trajectory_segment = trajectory[start:end, :]
            xtraj = trajectory_segment[:, 0]
            ytraj = trajectory_segment[:, 1]

            # Generate frames
            for pos in range(nposframe):
                frame_spot = gaussian_2d(
                    xtraj[pos], ytraj[pos], 2.35 * fwhm_psf / pixelsize,
                    npixel * factor_hr, flux
                )
                frame_hr[k] += frame_spot

            # Downsample and add noise
            frame_lr = block_reduce(frame_hr[k], block_size=factor_hr, func=np.mean)
            frame_noisy[k] = add_noise_background(
                frame_lr, background, poisson_noise, gaussian_noise, normalizeValue
            )
        # Store the noisy images
        image_array[p] = frame_noisy

        # Estimate D from the full trajectory
        msd_full = mean_square_displacement(trajectory)
        D_estimates[p] = estimateDfromMSD(msd_full, time_range)

        # Estimate D from centroids (coarse)
        D_estimates_coarse[p] = estimateDfromCentroids(trajectory, nframes, nposframe, dt)

    return image_array, D_estimates, D_estimates_coarse

# %%
trajectories = brownian_motion(nparticles, nframes, nposframe, DGen, dt)

# Generate images and estimate D
images, D_estimates_fine, D_estimates_coarse = generateImagesAndEstimateDFromTrajs(
    trajectories, nparticles, nframes, npixel=64, factor_hr=2, nposframe=nposframe, D=DGen ,dt=dt,
    fwhm_psf=300, pixelsize=100, flux=1000, background=10, poisson_noise=1, gaussian_noise=2)


# Print estimated D values
for p in range(nparticles):
    print(f"Particle {p}: Fine D = {D_estimates_fine[p]:.4f}, Coarse D = {D_estimates_coarse[p]:.4f}")
# Out:
# Particle 0: Fine D = 16586.3736, Coarse D = 16615.3678
# Particle 1: Fine D = 35038.3248, Coarse D = 35252.0610
# Particle 2: Fine D = 11652.5586, Coarse D = 11167.8843
# Particle 3: Fine D = 8913.0643, Coarse D = 8248.5844
# Particle 4: Fine D = 10447.4805, Coarse D = 10136.3665
# Particle 5: Fine D = 5526.1569, Coarse D = 4569.9339
# Particle 6: Fine D = 7690.6643, Coarse D = 7766.2538
# Particle 7: Fine D = 11138.1230, Coarse D = 10208.1869
# Particle 8: Fine D = 8348.0527, Coarse D = 7060.5041
# Particle 9: Fine D = 2526.1939, Coarse D = 2133.1204
# Particle 10: Fine D = 8782.5688, Coarse D = 7920.5906
# Particle 11: Fine D = 6594.5846, Coarse D = 6576.9989
# Particle 12: Fine D = 2754.4075, Coarse D = 2188.6867
# Particle 13: Fine D = 28630.9648, Coarse D = 27926.7614
# Particle 14: Fine D = 9188.8462, Coarse D = 8712.0771
# Particle 15: Fine D = 4282.5387, Coarse D = 4181.7186
# Particle 16: Fine D = 12014.9077, Coarse D = 11561.4556
# Particle 17: Fine D = 8852.2772, Coarse D = 8520.6862
# Particle 18: Fine D = 1897.2145, Coarse D = 1480.7036
# Particle 19: Fine D = 5238.5042, Coarse D = 4657.2249
# Particle 20: Fine D = 1853.0313, Coarse D = 1421.0657
# Particle 21: Fine D = 9141.1960, Coarse D = 8676.2481
# Particle 22: Fine D = 10113.4219, Coarse D = 9687.8723
# Particle 23: Fine D = 5777.5903, Coarse D = 5944.2707
# Particle 24: Fine D = 1626.1863, Coarse D = 1233.1648
# Particle 25: Fine D = 13119.8509, Coarse D = 12418.1206
# Particle 26: Fine D = 13060.9990, Coarse D = 12347.6748
# Particle 27: Fine D = 4220.3398, Coarse D = 4243.0626
# Particle 28: Fine D = 8991.1214, Coarse D = 7638.0334
# Particle 29: Fine D = 1928.5223, Coarse D = 1400.7714
# Particle 30: Fine D = 9037.5977, Coarse D = 9040.2522
# Particle 31: Fine D = 3598.9691, Coarse D = 2951.8826
# Particle 32: Fine D = 4718.4226, Coarse D = 4447.8916
# Particle 33: Fine D = 12374.5918, Coarse D = 11158.0212
# Particle 34: Fine D = 19790.3008, Coarse D = 18871.4233
# Particle 35: Fine D = 2142.8505, Coarse D = 1848.3945
# Particle 36: Fine D = 5718.8271, Coarse D = 4943.9527
# Particle 37: Fine D = 14118.4947, Coarse D = 14559.3066
# Particle 38: Fine D = 6370.3889, Coarse D = 5901.9138
# Particle 39: Fine D = 3316.0419, Coarse D = 3040.8313
# Particle 40: Fine D = 45486.3239, Coarse D = 43865.3035
# Particle 41: Fine D = 1460.9162, Coarse D = 1191.7450
# Particle 42: Fine D = 12410.1849, Coarse D = 12515.4736
# Particle 43: Fine D = 16814.6138, Coarse D = 16817.2459
# Particle 44: Fine D = 19457.7274, Coarse D = 19674.3413
# Particle 45: Fine D = 8527.5043, Coarse D = 8309.2152
# Particle 46: Fine D = 5448.8193, Coarse D = 4891.9201
# Particle 47: Fine D = 14864.8242, Coarse D = 14869.3871
# Particle 48: Fine D = 9916.0391, Coarse D = 9211.1233
# Particle 49: Fine D = 13085.0611, Coarse D = 12779.5767
# Particle 50: Fine D = 10945.7661, Coarse D = 10319.9518
# Particle 51: Fine D = 3136.8885, Coarse D = 3122.7307
# Particle 52: Fine D = 1908.4915, Coarse D = 1687.9084
# Particle 53: Fine D = 7987.1571, Coarse D = 7553.6309
# Particle 54: Fine D = 5815.2650, Coarse D = 5041.4074
# Particle 55: Fine D = 7989.4872, Coarse D = 8563.8715
# Particle 56: Fine D = 14503.5562, Coarse D = 14196.1546
# Particle 57: Fine D = 23555.6406, Coarse D = 22258.5886
# Particle 58: Fine D = 10065.3088, Coarse D = 10598.0757
# Particle 59: Fine D = 5273.4451, Coarse D = 4314.3237
# Particle 60: Fine D = 4763.2247, Coarse D = 3919.3707
# Particle 61: Fine D = 4681.4743, Coarse D = 4218.7702
# Particle 62: Fine D = 14689.4228, Coarse D = 14035.0408
# Particle 63: Fine D = 6437.3103, Coarse D = 5847.5631
# Particle 64: Fine D = 5466.7471, Coarse D = 5657.3659
# Particle 65: Fine D = 7301.1679, Coarse D = 6691.7587
# Particle 66: Fine D = 7253.8682, Coarse D = 7067.3304
# Particle 67: Fine D = 9294.5594, Coarse D = 8741.0512
# Particle 68: Fine D = 1538.2630, Coarse D = 1220.2745
# Particle 69: Fine D = 1797.7917, Coarse D = 1624.4258
# Particle 70: Fine D = 15763.9046, Coarse D = 14064.1089
# Particle 71: Fine D = 11713.5666, Coarse D = 9797.8384
# Particle 72: Fine D = 8610.2789, Coarse D = 7567.4754
# Particle 73: Fine D = 3713.7159, Coarse D = 3643.1817
# Particle 74: Fine D = 10548.8603, Coarse D = 11066.1608
# Particle 75: Fine D = 4194.2739, Coarse D = 3875.6354
# Particle 76: Fine D = 4735.7951, Coarse D = 4460.3709
# Particle 77: Fine D = 14571.4034, Coarse D = 13590.9162
# Particle 78: Fine D = 21110.0555, Coarse D = 19821.3153
# Particle 79: Fine D = 8712.3786, Coarse D = 8271.7035
# Particle 80: Fine D = 12951.2740, Coarse D = 12048.5728
# Particle 81: Fine D = 19306.4374, Coarse D = 18763.1767
# Particle 82: Fine D = 7647.0456, Coarse D = 6951.8838
# Particle 83: Fine D = 11037.3339, Coarse D = 10645.0618
# Particle 84: Fine D = 14190.1233, Coarse D = 13478.8097
# Particle 85: Fine D = 2704.6236, Coarse D = 2458.8193
# Particle 86: Fine D = 7893.7159, Coarse D = 7671.9952
# Particle 87: Fine D = 9704.2133, Coarse D = 8970.3641
# Particle 88: Fine D = 1867.1144, Coarse D = 1548.3741
# Particle 89: Fine D = 21545.9254, Coarse D = 19461.5712
# Particle 90: Fine D = 3332.4343, Coarse D = 2772.2921
# Particle 91: Fine D = 21540.4153, Coarse D = 20379.4835
# Particle 92: Fine D = 2202.2879, Coarse D = 1562.1410
# Particle 93: Fine D = 9501.0290, Coarse D = 8495.1604
# Particle 94: Fine D = 15465.5407, Coarse D = 14825.3924
# Particle 95: Fine D = 4253.7005, Coarse D = 4309.8620
# Particle 96: Fine D = 14005.8755, Coarse D = 13471.0163
# Particle 97: Fine D = 15687.8923, Coarse D = 15064.1749
# Particle 98: Fine D = 16969.7661, Coarse D = 15363.1095
# Particle 99: Fine D = 12253.1081, Coarse D = 11921.4845
# Particle 100: Fine D = 6849.0675, Coarse D = 6917.9536
# Particle 101: Fine D = 2595.8016, Coarse D = 2122.7372
# Particle 102: Fine D = 6929.0040, Coarse D = 6648.4273
# Particle 103: Fine D = 3499.8669, Coarse D = 2816.1588
# Particle 104: Fine D = 2515.8500, Coarse D = 1893.4242
# Particle 105: Fine D = 5744.8743, Coarse D = 5045.1649
# Particle 106: Fine D = 1441.2527, Coarse D = 1172.7994
# Particle 107: Fine D = 6924.4934, Coarse D = 5828.5263
# Particle 108: Fine D = 5162.6673, Coarse D = 4661.5567
# Particle 109: Fine D = 9093.6836, Coarse D = 8446.0551
# Particle 110: Fine D = 9014.1379, Coarse D = 8185.9253
# Particle 111: Fine D = 7662.4151, Coarse D = 7665.6896
# Particle 112: Fine D = 11683.5499, Coarse D = 10950.2386
# Particle 113: Fine D = 23991.9344, Coarse D = 21595.0585
# Particle 114: Fine D = 8021.8768, Coarse D = 7550.6333
# Particle 115: Fine D = 3686.6484, Coarse D = 3302.8170
# Particle 116: Fine D = 4521.2853, Coarse D = 4372.0028
# Particle 117: Fine D = 4268.8213, Coarse D = 3428.9537
# Particle 118: Fine D = 2382.5940, Coarse D = 2116.7501
# Particle 119: Fine D = 10636.0510, Coarse D = 10072.6506
# Particle 120: Fine D = 6835.5974, Coarse D = 5846.8815
# Particle 121: Fine D = 5248.8802, Coarse D = 5149.7586
# Particle 122: Fine D = 3073.3868, Coarse D = 2642.9337
# Particle 123: Fine D = 10215.7376, Coarse D = 9318.5718
# Particle 124: Fine D = 10246.6823, Coarse D = 9131.2634
# Particle 125: Fine D = 8294.8319, Coarse D = 7953.1835
# Particle 126: Fine D = 6057.2435, Coarse D = 5196.2584
# Particle 127: Fine D = 17867.8588, Coarse D = 16381.5482
# Particle 128: Fine D = 5138.9639, Coarse D = 4800.2758
# Particle 129: Fine D = 5281.4523, Coarse D = 5476.0384
# Particle 130: Fine D = 9134.8338, Coarse D = 8989.1747
# Particle 131: Fine D = 21794.3671, Coarse D = 21656.7855
# Particle 132: Fine D = 12112.8505, Coarse D = 12773.9794
# Particle 133: Fine D = 8730.0003, Coarse D = 7146.8527
# Particle 134: Fine D = 9624.7529, Coarse D = 9526.5998
# Particle 135: Fine D = 22901.9801, Coarse D = 21212.8129
# Particle 136: Fine D = 2743.0566, Coarse D = 1989.2776
# Particle 137: Fine D = 3838.2033, Coarse D = 3651.5023
# Particle 138: Fine D = 1425.9979, Coarse D = 1187.1046
# Particle 139: Fine D = 2002.7253, Coarse D = 1793.3299
# Particle 140: Fine D = 5063.0356, Coarse D = 4732.3196
# Particle 141: Fine D = 2896.8235, Coarse D = 2668.4940
# Particle 142: Fine D = 3766.3594, Coarse D = 3507.2816
# Particle 143: Fine D = 4531.7763, Coarse D = 4256.2583
# Particle 144: Fine D = 26589.4656, Coarse D = 25599.7673
# Particle 145: Fine D = 21949.2207, Coarse D = 21039.6261
# Particle 146: Fine D = 7915.0717, Coarse D = 7678.1104
# Particle 147: Fine D = 8310.2555, Coarse D = 7851.8013
# Particle 148: Fine D = 8435.7236, Coarse D = 8031.6759
# Particle 149: Fine D = 15365.6053, Coarse D = 15111.4901
# Particle 150: Fine D = 6104.8957, Coarse D = 5869.0398
# Particle 151: Fine D = 12378.5199, Coarse D = 11069.4201
# Particle 152: Fine D = 2464.2974, Coarse D = 1766.8165
# Particle 153: Fine D = 8736.0362, Coarse D = 8015.0137
# Particle 154: Fine D = 12104.8395, Coarse D = 11745.5342
# Particle 155: Fine D = 2069.7534, Coarse D = 1759.3655
# Particle 156: Fine D = 7208.7273, Coarse D = 6959.9243
# Particle 157: Fine D = 4402.8117, Coarse D = 4249.6440
# Particle 158: Fine D = 12229.2085, Coarse D = 11385.2264
# Particle 159: Fine D = 2827.0017, Coarse D = 2202.7489
# Particle 160: Fine D = 18104.4943, Coarse D = 19133.0319
# Particle 161: Fine D = 13375.5810, Coarse D = 13362.3409
# Particle 162: Fine D = 4079.0836, Coarse D = 3000.2534
# Particle 163: Fine D = 11088.3982, Coarse D = 10354.8762
# Particle 164: Fine D = 6867.3044, Coarse D = 6599.7771
# Particle 165: Fine D = 7341.5520, Coarse D = 7188.2553
# Particle 166: Fine D = 19562.0836, Coarse D = 19710.2274
# Particle 167: Fine D = 8976.9485, Coarse D = 9335.6853
# Particle 168: Fine D = 3994.3403, Coarse D = 3667.3601
# Particle 169: Fine D = 12758.1089, Coarse D = 11767.2336
# Particle 170: Fine D = 5153.4261, Coarse D = 4472.0773
# Particle 171: Fine D = 8182.5528, Coarse D = 7842.6916
# Particle 172: Fine D = 6330.3820, Coarse D = 5462.4106
# Particle 173: Fine D = 2907.8440, Coarse D = 2458.5457
# Particle 174: Fine D = 7962.9148, Coarse D = 7694.0132
# Particle 175: Fine D = 11927.0911, Coarse D = 12260.3077
# Particle 176: Fine D = 13881.4689, Coarse D = 12653.2599
# Particle 177: Fine D = 1185.4321, Coarse D = 724.5709
# Particle 178: Fine D = 11518.5978, Coarse D = 10705.2884
# Particle 179: Fine D = 9449.9450, Coarse D = 9558.6860
# Particle 180: Fine D = 5279.1742, Coarse D = 4725.3831
# Particle 181: Fine D = 7739.8583, Coarse D = 7343.4146
# Particle 182: Fine D = 17913.1102, Coarse D = 17282.1791
# Particle 183: Fine D = 10793.6145, Coarse D = 10631.8562
# Particle 184: Fine D = 13505.1590, Coarse D = 13319.8847
# Particle 185: Fine D = 15098.2175, Coarse D = 14717.6015
# Particle 186: Fine D = 32434.3331, Coarse D = 33470.6787
# Particle 187: Fine D = 8571.5688, Coarse D = 8726.9720
# Particle 188: Fine D = 20437.6398, Coarse D = 21233.2134
# Particle 189: Fine D = 14754.6077, Coarse D = 14852.4313
# Particle 190: Fine D = 5279.5582, Coarse D = 4578.9392
# Particle 191: Fine D = 1853.6227, Coarse D = 1474.8517
# Particle 192: Fine D = 8136.7496, Coarse D = 7647.7622
# Particle 193: Fine D = 10293.0770, Coarse D = 10600.7575
# Particle 194: Fine D = 4005.3574, Coarse D = 3782.4566
# Particle 195: Fine D = 8905.7078, Coarse D = 8372.0292
# Particle 196: Fine D = 5654.3377, Coarse D = 5321.1195
# Particle 197: Fine D = 8391.9603, Coarse D = 8025.8825
# Particle 198: Fine D = 7918.6545, Coarse D = 8188.6187
# Particle 199: Fine D = 15574.4866, Coarse D = 15282.8489
# Particle 200: Fine D = 11771.0356, Coarse D = 11281.3060
# Particle 201: Fine D = 6242.3926, Coarse D = 5641.3820
# Particle 202: Fine D = 14791.2195, Coarse D = 15265.3739
# Particle 203: Fine D = 35479.7272, Coarse D = 34752.2674
# Particle 204: Fine D = 11115.2556, Coarse D = 9270.7560
# Particle 205: Fine D = 19227.6826, Coarse D = 17558.0976
# Particle 206: Fine D = 12767.9487, Coarse D = 12200.9668
# Particle 207: Fine D = 10539.2962, Coarse D = 9328.6447
# Particle 208: Fine D = 37142.8557, Coarse D = 34782.0544
# Particle 209: Fine D = 29243.5073, Coarse D = 27277.5771
# Particle 210: Fine D = 11831.8448, Coarse D = 10699.5994
# Particle 211: Fine D = 2296.8398, Coarse D = 1881.1878
# Particle 212: Fine D = 2197.2206, Coarse D = 2086.7527
# Particle 213: Fine D = 2983.9817, Coarse D = 2777.0175
# Particle 214: Fine D = 23523.5777, Coarse D = 22226.5162
# Particle 215: Fine D = 5216.9807, Coarse D = 4521.9910
# Particle 216: Fine D = 17727.6006, Coarse D = 17353.2877
# Particle 217: Fine D = 4329.8632, Coarse D = 3960.6734
# Particle 218: Fine D = 5587.0363, Coarse D = 4357.3219
# Particle 219: Fine D = 1898.9534, Coarse D = 1671.2072
# Particle 220: Fine D = 9227.6149, Coarse D = 8883.6212
# Particle 221: Fine D = 8323.1590, Coarse D = 8370.5493
# Particle 222: Fine D = 14566.6139, Coarse D = 13723.3811
# Particle 223: Fine D = 22399.8365, Coarse D = 22140.9407
# Particle 224: Fine D = 9524.4054, Coarse D = 9204.3063
# Particle 225: Fine D = 6716.1523, Coarse D = 6287.7160
# Particle 226: Fine D = 8702.4876, Coarse D = 7380.0641
# Particle 227: Fine D = 15107.3917, Coarse D = 14987.5911
# Particle 228: Fine D = 1404.7244, Coarse D = 1145.6585
# Particle 229: Fine D = 16499.0370, Coarse D = 15739.3465
# Particle 230: Fine D = 6682.1426, Coarse D = 6596.6137
# Particle 231: Fine D = 4491.6368, Coarse D = 4365.6546
# Particle 232: Fine D = 4266.4078, Coarse D = 3648.1830
# Particle 233: Fine D = 12761.8752, Coarse D = 12126.9837
# Particle 234: Fine D = 7282.0599, Coarse D = 6830.0582
# Particle 235: Fine D = 7038.3280, Coarse D = 6492.4516
# Particle 236: Fine D = 7786.9868, Coarse D = 7990.9961
# Particle 237: Fine D = 18226.0744, Coarse D = 16803.3855
# Particle 238: Fine D = 28237.3040, Coarse D = 27683.7425
# Particle 239: Fine D = 3702.1042, Coarse D = 2917.1768
# Particle 240: Fine D = 5316.9130, Coarse D = 4403.0793
# Particle 241: Fine D = 10541.6683, Coarse D = 9973.1523
# Particle 242: Fine D = 14443.8185, Coarse D = 12673.3617
# Particle 243: Fine D = 19583.3731, Coarse D = 18820.1584
# Particle 244: Fine D = 15845.1778, Coarse D = 15604.7966
# Particle 245: Fine D = 3285.1622, Coarse D = 2885.1164
# Particle 246: Fine D = 3598.7674, Coarse D = 3483.4175
# Particle 247: Fine D = 6238.8522, Coarse D = 6155.2586
# Particle 248: Fine D = 6681.2527, Coarse D = 6585.1338
# Particle 249: Fine D = 25023.9737, Coarse D = 24150.0424
# Particle 250: Fine D = 1916.7997, Coarse D = 1682.8972
# Particle 251: Fine D = 16151.0759, Coarse D = 13524.5852
# Particle 252: Fine D = 4350.5613, Coarse D = 4369.7382
# Particle 253: Fine D = 4880.2714, Coarse D = 4584.7121
# Particle 254: Fine D = 4856.6641, Coarse D = 4894.6292
# Particle 255: Fine D = 11561.9596, Coarse D = 10372.3847
# Particle 256: Fine D = 9191.1299, Coarse D = 8417.2886
# Particle 257: Fine D = 2655.1253, Coarse D = 2078.7078
# Particle 258: Fine D = 6357.4530, Coarse D = 5809.3545
# Particle 259: Fine D = 12840.8710, Coarse D = 13096.4624
# Particle 260: Fine D = 10689.9182, Coarse D = 9458.5038
# Particle 261: Fine D = 7602.4007, Coarse D = 6911.1064
# Particle 262: Fine D = 2569.2174, Coarse D = 1886.0456
# Particle 263: Fine D = 1737.9062, Coarse D = 1565.2190
# Particle 264: Fine D = 2617.7668, Coarse D = 1821.6993
# Particle 265: Fine D = 6228.8789, Coarse D = 5772.2199
# Particle 266: Fine D = 2851.3293, Coarse D = 2414.8788
# Particle 267: Fine D = 2499.8843, Coarse D = 2337.2950
# Particle 268: Fine D = 29077.4381, Coarse D = 25182.9015
# Particle 269: Fine D = 21308.5008, Coarse D = 19916.7129
# Particle 270: Fine D = 1502.9507, Coarse D = 1273.6489
# Particle 271: Fine D = 4918.9339, Coarse D = 4721.1271
# Particle 272: Fine D = 5779.1224, Coarse D = 5286.8581
# Particle 273: Fine D = 3053.4623, Coarse D = 2724.9226
# Particle 274: Fine D = 12339.4013, Coarse D = 12943.1970
# Particle 275: Fine D = 15785.9488, Coarse D = 14823.4155
# Particle 276: Fine D = 15619.2211, Coarse D = 15636.8423
# Particle 277: Fine D = 5491.3133, Coarse D = 5227.3626
# Particle 278: Fine D = 21159.4680, Coarse D = 21316.5979
# Particle 279: Fine D = 7256.1419, Coarse D = 6650.8253
# Particle 280: Fine D = 9133.0342, Coarse D = 9197.6394
# Particle 281: Fine D = 4927.2311, Coarse D = 4855.5820
# Particle 282: Fine D = 26405.2446, Coarse D = 26396.6704
# Particle 283: Fine D = 24886.5182, Coarse D = 23551.8211
# Particle 284: Fine D = 12041.1072, Coarse D = 12448.6444
# Particle 285: Fine D = 1584.6050, Coarse D = 1203.0508
# Particle 286: Fine D = 20630.2455, Coarse D = 19450.3055
# Particle 287: Fine D = 20592.0647, Coarse D = 19436.4399
# Particle 288: Fine D = 4644.1975, Coarse D = 4259.5758
# Particle 289: Fine D = 3244.5183, Coarse D = 3151.6672
# Particle 290: Fine D = 7741.9202, Coarse D = 7562.2177
# Particle 291: Fine D = 3257.3272, Coarse D = 3170.3888
# Particle 292: Fine D = 6477.9300, Coarse D = 5918.9144
# Particle 293: Fine D = 10675.4794, Coarse D = 10459.7960
# Particle 294: Fine D = 3670.2074, Coarse D = 3308.7004
# Particle 295: Fine D = 11050.4547, Coarse D = 11147.0102
# Particle 296: Fine D = 7548.7620, Coarse D = 6803.5362
# Particle 297: Fine D = 13709.8412, Coarse D = 13437.9989
# Particle 298: Fine D = 8755.1743, Coarse D = 7585.5779
# Particle 299: Fine D = 21151.5988, Coarse D = 20287.2061
# Particle 300: Fine D = 38778.1563, Coarse D = 37948.2235
# Particle 301: Fine D = 1618.8831, Coarse D = 1136.4086
# Particle 302: Fine D = 7649.5639, Coarse D = 7861.0671
# Particle 303: Fine D = 9066.8084, Coarse D = 8506.6569
# Particle 304: Fine D = 1941.1706, Coarse D = 1362.3478
# Particle 305: Fine D = 10558.6796, Coarse D = 9804.6230
# Particle 306: Fine D = 7959.1169, Coarse D = 7367.5751
# Particle 307: Fine D = 3267.8329, Coarse D = 3064.2721
# Particle 308: Fine D = 23620.6944, Coarse D = 23354.9002
# Particle 309: Fine D = 11330.0913, Coarse D = 11891.5759
# Particle 310: Fine D = 1165.3851, Coarse D = 698.1646
# Particle 311: Fine D = 13089.4195, Coarse D = 12984.3962
# Particle 312: Fine D = 6007.1175, Coarse D = 5320.4792
# Particle 313: Fine D = 4815.2542, Coarse D = 4531.9924
# Particle 314: Fine D = 1575.6498, Coarse D = 1346.7108
# Particle 315: Fine D = 3261.2480, Coarse D = 3259.5569
# Particle 316: Fine D = 4797.7107, Coarse D = 4413.1905
# Particle 317: Fine D = 3470.1948, Coarse D = 2850.8039
# Particle 318: Fine D = 5540.7338, Coarse D = 4916.3399
# Particle 319: Fine D = 2438.1002, Coarse D = 1931.0602
# Particle 320: Fine D = 11803.7499, Coarse D = 12645.1445
# Particle 321: Fine D = 4186.7954, Coarse D = 3287.5605
# Particle 322: Fine D = 13491.9809, Coarse D = 13336.9246
# Particle 323: Fine D = 6157.7574, Coarse D = 5028.8193
# Particle 324: Fine D = 1897.1481, Coarse D = 1591.3512
# Particle 325: Fine D = 3284.0860, Coarse D = 2699.3112
# Particle 326: Fine D = 11238.1937, Coarse D = 9679.1120
# Particle 327: Fine D = 4514.1020, Coarse D = 4498.5212
# Particle 328: Fine D = 3760.8467, Coarse D = 3575.2821
# Particle 329: Fine D = 2667.8631, Coarse D = 1846.2138
# Particle 330: Fine D = 5493.7747, Coarse D = 5611.3048
# Particle 331: Fine D = 18972.2771, Coarse D = 17599.2223
# Particle 332: Fine D = 2302.1943, Coarse D = 1807.7006
# Particle 333: Fine D = 13075.9248, Coarse D = 12957.5596
# Particle 334: Fine D = 23317.0195, Coarse D = 22815.3542
# Particle 335: Fine D = 7479.8806, Coarse D = 8031.9536
# Particle 336: Fine D = 15239.7106, Coarse D = 13685.5394
# Particle 337: Fine D = 3943.1148, Coarse D = 3417.3337
# Particle 338: Fine D = 1614.0436, Coarse D = 1324.9076
# Particle 339: Fine D = 5695.0435, Coarse D = 5614.3543
# Particle 340: Fine D = 20905.7733, Coarse D = 19954.7937
# Particle 341: Fine D = 4035.3842, Coarse D = 3608.0160
# Particle 342: Fine D = 14442.0442, Coarse D = 14789.8178
# Particle 343: Fine D = 6208.7830, Coarse D = 5576.0541
# Particle 344: Fine D = 15453.7788, Coarse D = 14514.5710
# Particle 345: Fine D = 12589.6973, Coarse D = 11694.6921
# Particle 346: Fine D = 1333.6093, Coarse D = 983.4357
# Particle 347: Fine D = 5148.6905, Coarse D = 4554.8859
# Particle 348: Fine D = 6128.8311, Coarse D = 5247.0676
# Particle 349: Fine D = 19937.9101, Coarse D = 19465.6531
# Particle 350: Fine D = 6610.2196, Coarse D = 6332.8506
# Particle 351: Fine D = 2006.1578, Coarse D = 1669.1959
# Particle 352: Fine D = 1815.5124, Coarse D = 1629.1136
# Particle 353: Fine D = 7318.5135, Coarse D = 7116.9330
# Particle 354: Fine D = 1219.3873, Coarse D = 586.1184
# Particle 355: Fine D = 2319.6468, Coarse D = 2217.5671
# Particle 356: Fine D = 2859.0736, Coarse D = 2331.9078
# Particle 357: Fine D = 3760.6987, Coarse D = 3443.6109
# Particle 358: Fine D = 12446.1698, Coarse D = 12017.0222
# Particle 359: Fine D = 22478.6912, Coarse D = 23039.1133
# Particle 360: Fine D = 20736.9238, Coarse D = 20539.8527
# Particle 361: Fine D = 1929.0383, Coarse D = 1306.3245
# Particle 362: Fine D = 12744.1579, Coarse D = 12672.4778
# Particle 363: Fine D = 8663.5984, Coarse D = 7076.0842
# Particle 364: Fine D = 30005.5747, Coarse D = 28061.5493
# Particle 365: Fine D = 4962.8122, Coarse D = 4671.8602
# Particle 366: Fine D = 8278.8766, Coarse D = 7530.9869
# Particle 367: Fine D = 9517.3830, Coarse D = 8389.0056
# Particle 368: Fine D = 4789.3892, Coarse D = 3440.3659
# Particle 369: Fine D = 21426.6534, Coarse D = 21833.1517
# Particle 370: Fine D = 4034.3901, Coarse D = 3975.3170
# Particle 371: Fine D = 6016.8015, Coarse D = 5467.6696
# Particle 372: Fine D = 8198.7245, Coarse D = 7159.5870
# Particle 373: Fine D = 2288.5659, Coarse D = 2036.7623
# Particle 374: Fine D = 22277.6203, Coarse D = 20608.6408
# Particle 375: Fine D = 17515.8008, Coarse D = 15440.7667
# Particle 376: Fine D = 5092.7172, Coarse D = 4820.0481
# Particle 377: Fine D = 2886.7053, Coarse D = 2753.7879
# Particle 378: Fine D = 10366.0233, Coarse D = 9036.4783
# Particle 379: Fine D = 6267.2656, Coarse D = 6121.9779
# Particle 380: Fine D = 5473.9548, Coarse D = 5065.3794
# Particle 381: Fine D = 20540.4180, Coarse D = 19129.4284
# Particle 382: Fine D = 29676.7242, Coarse D = 28754.7856
# Particle 383: Fine D = 7486.1820, Coarse D = 6975.9217
# Particle 384: Fine D = 5789.6169, Coarse D = 5920.3206
# Particle 385: Fine D = 16023.9558, Coarse D = 15921.4437
# Particle 386: Fine D = 10239.5430, Coarse D = 9205.0547
# Particle 387: Fine D = 8375.8677, Coarse D = 7312.0665
# Particle 388: Fine D = 9089.5205, Coarse D = 8892.2096
# Particle 389: Fine D = 3665.3932, Coarse D = 3289.4745
# Particle 390: Fine D = 4205.4381, Coarse D = 3978.6380
# Particle 391: Fine D = 6675.7789, Coarse D = 6333.6578
# Particle 392: Fine D = 8880.5481, Coarse D = 8739.8563
# Particle 393: Fine D = 13454.3058, Coarse D = 12270.9250
# Particle 394: Fine D = 16242.6788, Coarse D = 15142.5437
# Particle 395: Fine D = 12078.6646, Coarse D = 11070.7269
# Particle 396: Fine D = 8470.8250, Coarse D = 7578.2699
# Particle 397: Fine D = 1782.6906, Coarse D = 1312.2157
# Particle 398: Fine D = 7992.7665, Coarse D = 7473.6728
# Particle 399: Fine D = 12804.3913, Coarse D = 12775.9111
# Particle 400: Fine D = 3951.8891, Coarse D = 3341.9504
# Particle 401: Fine D = 16616.3691, Coarse D = 14956.3381
# Particle 402: Fine D = 2352.5120, Coarse D = 1996.7814
# Particle 403: Fine D = 11016.4096, Coarse D = 10510.9410
# Particle 404: Fine D = 12616.3551, Coarse D = 11603.9602
# Particle 405: Fine D = 10575.1463, Coarse D = 10827.0939
# Particle 406: Fine D = 6790.5541, Coarse D = 6248.5685
# Particle 407: Fine D = 3031.8100, Coarse D = 2310.7303
# Particle 408: Fine D = 12030.5205, Coarse D = 12058.5263
# Particle 409: Fine D = 2662.9037, Coarse D = 2398.8824
# Particle 410: Fine D = 5040.0207, Coarse D = 5047.6658
# Particle 411: Fine D = 20954.0827, Coarse D = 19939.8311
# Particle 412: Fine D = 9028.8438, Coarse D = 7773.6094
# Particle 413: Fine D = 5723.7405, Coarse D = 4866.2001
# Particle 414: Fine D = 7424.1880, Coarse D = 6651.5100
# Particle 415: Fine D = 2911.0361, Coarse D = 2522.2765
# Particle 416: Fine D = 10751.3029, Coarse D = 9996.9512
# Particle 417: Fine D = 8466.1517, Coarse D = 6577.0085
# Particle 418: Fine D = 15054.8055, Coarse D = 12929.2814
# Particle 419: Fine D = 11813.0400, Coarse D = 10320.4255
# Particle 420: Fine D = 5322.6400, Coarse D = 4749.2507
# Particle 421: Fine D = 4918.5234, Coarse D = 4162.8226
# Particle 422: Fine D = 5904.3763, Coarse D = 5562.9558
# Particle 423: Fine D = 2802.7776, Coarse D = 2415.5459
# Particle 424: Fine D = 19824.8529, Coarse D = 19593.4498
# Particle 425: Fine D = 2520.6004, Coarse D = 2337.2349
# Particle 426: Fine D = 16845.7555, Coarse D = 16809.6869
# Particle 427: Fine D = 7812.0761, Coarse D = 7384.6075
# Particle 428: Fine D = 20445.5951, Coarse D = 18649.4189
# Particle 429: Fine D = 24877.7391, Coarse D = 23190.3647
# Particle 430: Fine D = 8088.5239, Coarse D = 7731.5634
# Particle 431: Fine D = 9342.4902, Coarse D = 8907.5108
# Particle 432: Fine D = 18677.7236, Coarse D = 18169.9709
# Particle 433: Fine D = 16831.3580, Coarse D = 16859.1494
# Particle 434: Fine D = 4157.6372, Coarse D = 3422.6913
# Particle 435: Fine D = 18427.3667, Coarse D = 17937.7052
# Particle 436: Fine D = 13560.2302, Coarse D = 12299.7390
# Particle 437: Fine D = 3792.9264, Coarse D = 3551.6881
# Particle 438: Fine D = 7727.4567, Coarse D = 6521.1772
# Particle 439: Fine D = 11206.2983, Coarse D = 9888.7287
# Particle 440: Fine D = 2105.3396, Coarse D = 1497.1634
# Particle 441: Fine D = 3473.9316, Coarse D = 3211.4551
# Particle 442: Fine D = 5363.3191, Coarse D = 5038.0820
# Particle 443: Fine D = 3173.0087, Coarse D = 3166.1460
# Particle 444: Fine D = 6116.5423, Coarse D = 5396.4557
# Particle 445: Fine D = 3910.6816, Coarse D = 3554.9527
# Particle 446: Fine D = 2333.2956, Coarse D = 1695.7357
# Particle 447: Fine D = 19689.9806, Coarse D = 19419.9812
# Particle 448: Fine D = 10139.3221, Coarse D = 9801.7504
# Particle 449: Fine D = 9902.7314, Coarse D = 8749.8550
# Particle 450: Fine D = 5993.9735, Coarse D = 5938.2739
# Particle 451: Fine D = 4542.9595, Coarse D = 3578.9179
# Particle 452: Fine D = 4624.5737, Coarse D = 3510.2920
# Particle 453: Fine D = 3260.8903, Coarse D = 2954.3229
# Particle 454: Fine D = 3354.3329, Coarse D = 3060.9738
# Particle 455: Fine D = 14194.4236, Coarse D = 15019.1903
# Particle 456: Fine D = 3512.0874, Coarse D = 3261.0591
# Particle 457: Fine D = 12315.3179, Coarse D = 12036.5245
# Particle 458: Fine D = 10352.1638, Coarse D = 9924.7146
# Particle 459: Fine D = 4415.2471, Coarse D = 3949.8632
# Particle 460: Fine D = 30660.0505, Coarse D = 28698.7142
# Particle 461: Fine D = 9467.2381, Coarse D = 9703.3229
# Particle 462: Fine D = 3248.0864, Coarse D = 2465.3735
# Particle 463: Fine D = 10715.5117, Coarse D = 9123.3016
# Particle 464: Fine D = 10564.1986, Coarse D = 10067.7531
# Particle 465: Fine D = 10759.0873, Coarse D = 10285.8480
# Particle 466: Fine D = 5288.3673, Coarse D = 4429.9802
# Particle 467: Fine D = 7372.4794, Coarse D = 6908.6403
# Particle 468: Fine D = 6648.4876, Coarse D = 6783.2717
# Particle 469: Fine D = 10664.4804, Coarse D = 9129.2500
# Particle 470: Fine D = 4895.2418, Coarse D = 3011.7067
# Particle 471: Fine D = 6849.3618, Coarse D = 6073.0503
# Particle 472: Fine D = 8668.7837, Coarse D = 8547.7659
# Particle 473: Fine D = 2786.0416, Coarse D = 2501.0085
# Particle 474: Fine D = 9940.7602, Coarse D = 9995.6413
# Particle 475: Fine D = 11841.2270, Coarse D = 12036.2426
# Particle 476: Fine D = 6760.1245, Coarse D = 5230.1393
# Particle 477: Fine D = 7076.1246, Coarse D = 6829.4903
# Particle 478: Fine D = 8766.0955, Coarse D = 8096.5052
# Particle 479: Fine D = 4067.4016, Coarse D = 3827.8893
# Particle 480: Fine D = 3008.1595, Coarse D = 2321.9903
# Particle 481: Fine D = 2526.1812, Coarse D = 2070.5390
# Particle 482: Fine D = 3140.4681, Coarse D = 2469.1076
# Particle 483: Fine D = 13809.8942, Coarse D = 14211.4988
# Particle 484: Fine D = 11545.9955, Coarse D = 11876.0999
# Particle 485: Fine D = 22854.6623, Coarse D = 22046.3767
# Particle 486: Fine D = 37468.4390, Coarse D = 35226.7813
# Particle 487: Fine D = 6470.1174, Coarse D = 6054.8108
# Particle 488: Fine D = 4806.6020, Coarse D = 4891.2330
# Particle 489: Fine D = 8340.8432, Coarse D = 7738.9063
# Particle 490: Fine D = 12836.4583, Coarse D = 13255.2696
# Particle 491: Fine D = 8921.4396, Coarse D = 7864.5499
# Particle 492: Fine D = 4093.9754, Coarse D = 4006.2157
# Particle 493: Fine D = 8677.1255, Coarse D = 7681.5145
# Particle 494: Fine D = 9084.8223, Coarse D = 8185.3393
# Particle 495: Fine D = 13400.8433, Coarse D = 13167.8522
# Particle 496: Fine D = 22798.2804, Coarse D = 21999.8329
# Particle 497: Fine D = 4065.5989, Coarse D = 4203.4762
# Particle 498: Fine D = 5175.4277, Coarse D = 4854.8061
# Particle 499: Fine D = 5806.9934, Coarse D = 5285.6308
# Particle 500: Fine D = 1483.5095, Coarse D = 1011.3399
# Particle 501: Fine D = 23935.2197, Coarse D = 24974.8734
# Particle 502: Fine D = 3640.5641, Coarse D = 3011.1376
# Particle 503: Fine D = 2237.1064, Coarse D = 1844.5775
# Particle 504: Fine D = 3356.1374, Coarse D = 2910.5229
# Particle 505: Fine D = 13122.3327, Coarse D = 13600.3529
# Particle 506: Fine D = 1765.1804, Coarse D = 1462.3390
# Particle 507: Fine D = 2621.0901, Coarse D = 2178.4507
# Particle 508: Fine D = 14282.3856, Coarse D = 12827.1803
# Particle 509: Fine D = 9829.7326, Coarse D = 10287.3374
# Particle 510: Fine D = 12091.9923, Coarse D = 11419.2893
# Particle 511: Fine D = 2993.1400, Coarse D = 2742.1247
# Particle 512: Fine D = 19061.5945, Coarse D = 17744.9638
# Particle 513: Fine D = 2812.2919, Coarse D = 2743.0660
# Particle 514: Fine D = 48791.1053, Coarse D = 45923.6714
# Particle 515: Fine D = 4776.9831, Coarse D = 4776.3754
# Particle 516: Fine D = 12219.0490, Coarse D = 10747.3190
# Particle 517: Fine D = 1687.1412, Coarse D = 1429.3481
# Particle 518: Fine D = 11821.3262, Coarse D = 11514.4123
# Particle 519: Fine D = 12432.2963, Coarse D = 12267.2030
# Particle 520: Fine D = 9042.7328, Coarse D = 9094.6555
# Particle 521: Fine D = 20572.2058, Coarse D = 18358.7852
# Particle 522: Fine D = 3793.1868, Coarse D = 3476.9747
# Particle 523: Fine D = 6149.2721, Coarse D = 6145.1903
# Particle 524: Fine D = 6491.5319, Coarse D = 6264.7518
# Particle 525: Fine D = 16822.1680, Coarse D = 15517.8898
# Particle 526: Fine D = 20966.3189, Coarse D = 20569.0653
# Particle 527: Fine D = 2934.5283, Coarse D = 2653.7075
# Particle 528: Fine D = 18051.1201, Coarse D = 18000.7647
# Particle 529: Fine D = 2003.6170, Coarse D = 1742.5881
# Particle 530: Fine D = 2644.7617, Coarse D = 2215.7085
# Particle 531: Fine D = 14299.8046, Coarse D = 13517.5076
# Particle 532: Fine D = 1821.2907, Coarse D = 1422.1024
# Particle 533: Fine D = 5568.1356, Coarse D = 4724.3339
# Particle 534: Fine D = 3056.2553, Coarse D = 2722.2761
# Particle 535: Fine D = 4031.9909, Coarse D = 3559.4750
# Particle 536: Fine D = 3946.4059, Coarse D = 3684.9776
# Particle 537: Fine D = 1694.0289, Coarse D = 1307.2272
# Particle 538: Fine D = 6899.8184, Coarse D = 6781.2917
# Particle 539: Fine D = 9280.9566, Coarse D = 9403.9887
# Particle 540: Fine D = 11763.0204, Coarse D = 10508.8113
# Particle 541: Fine D = 4037.7448, Coarse D = 3420.0235
# Particle 542: Fine D = 1676.3694, Coarse D = 1151.1500
# Particle 543: Fine D = 3591.6985, Coarse D = 2702.7799
# Particle 544: Fine D = 14291.9898, Coarse D = 13705.3962
# Particle 545: Fine D = 9058.8588, Coarse D = 7630.6109
# Particle 546: Fine D = 12379.7967, Coarse D = 9293.8702
# Particle 547: Fine D = 5354.7927, Coarse D = 5080.1488
# Particle 548: Fine D = 8707.3455, Coarse D = 7721.4772
# Particle 549: Fine D = 11827.0513, Coarse D = 11469.0467
# Particle 550: Fine D = 10508.9715, Coarse D = 10104.4240
# Particle 551: Fine D = 8236.8159, Coarse D = 8368.9625
# Particle 552: Fine D = 7620.8584, Coarse D = 7804.3492
# Particle 553: Fine D = 3906.6699, Coarse D = 3608.8801
# Particle 554: Fine D = 4128.9468, Coarse D = 3873.3370
# Particle 555: Fine D = 7186.6826, Coarse D = 5894.2349
# Particle 556: Fine D = 22739.4685, Coarse D = 22164.0192
# Particle 557: Fine D = 18658.3800, Coarse D = 17294.3267
# Particle 558: Fine D = 8796.7260, Coarse D = 7705.6820
# Particle 559: Fine D = 1086.4557, Coarse D = 812.3154
# Particle 560: Fine D = 2996.9143, Coarse D = 2623.6262
# Particle 561: Fine D = 15036.6071, Coarse D = 13606.7716
# Particle 562: Fine D = 4077.0730, Coarse D = 3701.3154
# Particle 563: Fine D = 6448.6391, Coarse D = 5522.4234
# Particle 564: Fine D = 4117.4760, Coarse D = 3275.3293
# Particle 565: Fine D = 17981.0997, Coarse D = 17577.8259
# Particle 566: Fine D = 17132.6405, Coarse D = 15432.8719
# Particle 567: Fine D = 5270.0582, Coarse D = 4919.0002
# Particle 568: Fine D = 11129.5387, Coarse D = 11249.9130
# Particle 569: Fine D = 8666.1386, Coarse D = 8671.2569
# Particle 570: Fine D = 3545.6874, Coarse D = 3102.9248
# Particle 571: Fine D = 4936.7519, Coarse D = 4323.2425
# Particle 572: Fine D = 6863.2991, Coarse D = 6346.0807
# Particle 573: Fine D = 5323.7930, Coarse D = 4045.7136
# Particle 574: Fine D = 4920.9185, Coarse D = 4144.3271
# Particle 575: Fine D = 9237.2701, Coarse D = 8777.5049
# Particle 576: Fine D = 18853.1297, Coarse D = 16251.0490
# Particle 577: Fine D = 7551.2586, Coarse D = 7494.2535
# Particle 578: Fine D = 17569.8446, Coarse D = 15790.3140
# Particle 579: Fine D = 1874.9626, Coarse D = 1392.1097
# Particle 580: Fine D = 11522.6189, Coarse D = 10359.5521
# Particle 581: Fine D = 13680.2354, Coarse D = 11669.0966
# Particle 582: Fine D = 8540.6575, Coarse D = 8042.9707
# Particle 583: Fine D = 20516.0191, Coarse D = 20359.0010
# Particle 584: Fine D = 1818.6567, Coarse D = 1412.6869
# Particle 585: Fine D = 13262.1419, Coarse D = 14035.2486
# Particle 586: Fine D = 3675.0893, Coarse D = 3154.8721
# Particle 587: Fine D = 8617.0275, Coarse D = 8341.3516
# Particle 588: Fine D = 20315.9464, Coarse D = 19751.4029
# Particle 589: Fine D = 2020.9266, Coarse D = 1638.9359
# Particle 590: Fine D = 7082.0210, Coarse D = 6895.2743
# Particle 591: Fine D = 3382.6904, Coarse D = 3006.2873
# Particle 592: Fine D = 8472.2393, Coarse D = 7221.7751
# Particle 593: Fine D = 14028.6101, Coarse D = 13501.0622
# Particle 594: Fine D = 3213.6970, Coarse D = 2860.2849
# Particle 595: Fine D = 2666.5721, Coarse D = 2355.7093
# Particle 596: Fine D = 18186.9257, Coarse D = 18293.6599
# Particle 597: Fine D = 13368.8590, Coarse D = 12784.8072
# Particle 598: Fine D = 13473.1140, Coarse D = 12970.7187
# Particle 599: Fine D = 3014.2435, Coarse D = 2863.2854
# Particle 600: Fine D = 5332.3280, Coarse D = 4377.2792
# Particle 601: Fine D = 1209.4505, Coarse D = 723.2233
# Particle 602: Fine D = 5548.1181, Coarse D = 5228.6428
# Particle 603: Fine D = 6436.6579, Coarse D = 5751.6499
# Particle 604: Fine D = 3294.1745, Coarse D = 2907.0371
# Particle 605: Fine D = 1696.9271, Coarse D = 1289.7824
# Particle 606: Fine D = 4708.1320, Coarse D = 4315.8370
# Particle 607: Fine D = 1784.7646, Coarse D = 1417.8668
# Particle 608: Fine D = 2538.5504, Coarse D = 1914.6583
# Particle 609: Fine D = 15881.0129, Coarse D = 15540.0533
# Particle 610: Fine D = 12682.5643, Coarse D = 12022.8724
# Particle 611: Fine D = 3539.8930, Coarse D = 3004.6882
# Particle 612: Fine D = 3745.3151, Coarse D = 3622.5773
# Particle 613: Fine D = 23956.3023, Coarse D = 21325.5619
# Particle 614: Fine D = 5131.6719, Coarse D = 4783.7253
# Particle 615: Fine D = 11119.2743, Coarse D = 9505.1163
# Particle 616: Fine D = 13502.8814, Coarse D = 12593.5793
# Particle 617: Fine D = 5919.3665, Coarse D = 5214.2619
# Particle 618: Fine D = 6444.2361, Coarse D = 5990.7691
# Particle 619: Fine D = 10142.1959, Coarse D = 9713.7316
# Particle 620: Fine D = 5129.4808, Coarse D = 4940.1119
# Particle 621: Fine D = 3393.1542, Coarse D = 3106.9930
# Particle 622: Fine D = 8809.7291, Coarse D = 7673.3077
# Particle 623: Fine D = 24831.4094, Coarse D = 25103.6085
# Particle 624: Fine D = 5326.5641, Coarse D = 4957.4247
# Particle 625: Fine D = 8856.4914, Coarse D = 8825.2993
# Particle 626: Fine D = 1641.1634, Coarse D = 1284.4820
# Particle 627: Fine D = 48354.2969, Coarse D = 47878.5147
# Particle 628: Fine D = 18022.8110, Coarse D = 18218.5175
# Particle 629: Fine D = 8491.1658, Coarse D = 8162.4180
# Particle 630: Fine D = 2614.0106, Coarse D = 1896.1168
# Particle 631: Fine D = 3520.4366, Coarse D = 3076.4502
# Particle 632: Fine D = 20552.8285, Coarse D = 20505.6983
# Particle 633: Fine D = 3937.6262, Coarse D = 3997.1661
# Particle 634: Fine D = 9115.8983, Coarse D = 8410.0405
# Particle 635: Fine D = 4466.8891, Coarse D = 4018.8703
# Particle 636: Fine D = 8994.7148, Coarse D = 8630.9175
# Particle 637: Fine D = 19206.6121, Coarse D = 17752.2793
# Particle 638: Fine D = 1501.1735, Coarse D = 808.2242
# Particle 639: Fine D = 5972.8763, Coarse D = 5901.8139
# Particle 640: Fine D = 17787.4787, Coarse D = 17762.6617
# Particle 641: Fine D = 14249.4578, Coarse D = 13099.8268
# Particle 642: Fine D = 6496.3980, Coarse D = 6357.6659
# Particle 643: Fine D = 18831.4362, Coarse D = 17898.5563
# Particle 644: Fine D = 10032.2919, Coarse D = 9097.1004
# Particle 645: Fine D = 9504.3958, Coarse D = 8949.2930
# Particle 646: Fine D = 12155.1358, Coarse D = 11579.2288
# Particle 647: Fine D = 5884.7088, Coarse D = 5106.5402
# Particle 648: Fine D = 3711.1675, Coarse D = 3680.3015
# Particle 649: Fine D = 20185.5420, Coarse D = 19716.3094
# Particle 650: Fine D = 2588.2646, Coarse D = 2328.9144
# Particle 651: Fine D = 4142.2890, Coarse D = 3757.1903
# Particle 652: Fine D = 9097.0385, Coarse D = 9143.2092
# Particle 653: Fine D = 20037.8447, Coarse D = 19337.0883
# Particle 654: Fine D = 5070.3376, Coarse D = 4389.5409
# Particle 655: Fine D = 3537.1720, Coarse D = 3420.7803
# Particle 656: Fine D = 7585.5639, Coarse D = 7098.3522
# Particle 657: Fine D = 6301.7027, Coarse D = 5468.9470
# Particle 658: Fine D = 6942.9010, Coarse D = 6183.3107
# Particle 659: Fine D = 19617.8712, Coarse D = 19541.9006
# Particle 660: Fine D = 10208.5234, Coarse D = 9584.6922
# Particle 661: Fine D = 10790.7175, Coarse D = 9908.9180
# Particle 662: Fine D = 1860.6996, Coarse D = 1399.5422
# Particle 663: Fine D = 13768.6391, Coarse D = 13153.2292
# Particle 664: Fine D = 1547.2295, Coarse D = 984.3833
# Particle 665: Fine D = 9876.8436, Coarse D = 9589.1237
# Particle 666: Fine D = 14988.1530, Coarse D = 15401.6193
# Particle 667: Fine D = 1622.1000, Coarse D = 1412.3768
# Particle 668: Fine D = 5366.9983, Coarse D = 5083.9276
# Particle 669: Fine D = 11028.8045, Coarse D = 10870.7853
# Particle 670: Fine D = 2481.0608, Coarse D = 1691.7460
# Particle 671: Fine D = 14549.1241, Coarse D = 15007.3616
# Particle 672: Fine D = 4593.8110, Coarse D = 4752.1096
# Particle 673: Fine D = 4887.8303, Coarse D = 4447.2092
# Particle 674: Fine D = 8358.9787, Coarse D = 7617.2733
# Particle 675: Fine D = 11089.8205, Coarse D = 9735.0835
# Particle 676: Fine D = 2975.3414, Coarse D = 2885.7118
# Particle 677: Fine D = 12016.0223, Coarse D = 11516.4442
# Particle 678: Fine D = 2605.9155, Coarse D = 2486.4971
# Particle 679: Fine D = 13560.9495, Coarse D = 13554.4391
# Particle 680: Fine D = 19111.4132, Coarse D = 18349.4432
# Particle 681: Fine D = 17999.7416, Coarse D = 17021.4327
# Particle 682: Fine D = 11815.3586, Coarse D = 12311.4826
# Particle 683: Fine D = 16471.0650, Coarse D = 14742.5167
# Particle 684: Fine D = 1229.8528, Coarse D = 958.4267
# Particle 685: Fine D = 12819.8303, Coarse D = 12927.2958
# Particle 686: Fine D = 8938.5238, Coarse D = 7460.4831
# Particle 687: Fine D = 14817.1107, Coarse D = 13565.6231
# Particle 688: Fine D = 22768.7395, Coarse D = 22862.8793
# Particle 689: Fine D = 5417.0993, Coarse D = 5010.9749
# Particle 690: Fine D = 3890.3045, Coarse D = 3028.0826
# Particle 691: Fine D = 5053.7746, Coarse D = 5228.5809
# Particle 692: Fine D = 1755.0032, Coarse D = 1330.9799
# Particle 693: Fine D = 21444.1521, Coarse D = 21823.4248
# Particle 694: Fine D = 2843.9349, Coarse D = 2343.0406
# Particle 695: Fine D = 1638.6986, Coarse D = 1418.6012
# Particle 696: Fine D = 7021.7083, Coarse D = 6574.8026
# Particle 697: Fine D = 6017.8731, Coarse D = 5827.6407
# Particle 698: Fine D = 2261.1820, Coarse D = 1469.7839
# Particle 699: Fine D = 5133.0775, Coarse D = 5226.1716
# Particle 700: Fine D = 5896.9144, Coarse D = 6112.2696
# Particle 701: Fine D = 15231.8513, Coarse D = 14680.8375
# Particle 702: Fine D = 5698.6511, Coarse D = 5383.1090
# Particle 703: Fine D = 6419.5265, Coarse D = 5995.9576
# Particle 704: Fine D = 15202.6581, Coarse D = 14909.7992
# Particle 705: Fine D = 6381.4099, Coarse D = 5905.3069
# Particle 706: Fine D = 37449.5507, Coarse D = 36480.3794
# Particle 707: Fine D = 1303.1389, Coarse D = 1012.0169
# Particle 708: Fine D = 5726.9980, Coarse D = 5784.4660
# Particle 709: Fine D = 4321.4145, Coarse D = 3955.8520
# Particle 710: Fine D = 4489.8041, Coarse D = 4424.7584
# Particle 711: Fine D = 4939.0489, Coarse D = 4841.3874
# Particle 712: Fine D = 23508.4537, Coarse D = 22428.4628
# Particle 713: Fine D = 23060.7913, Coarse D = 20464.2296
# Particle 714: Fine D = 8125.3698, Coarse D = 8108.9010
# Particle 715: Fine D = 3122.2598, Coarse D = 3096.7589
# Particle 716: Fine D = 31343.6866, Coarse D = 30144.0266
# Particle 717: Fine D = 2908.5789, Coarse D = 2690.8850
# Particle 718: Fine D = 8620.6644, Coarse D = 7510.5629
# Particle 719: Fine D = 17981.7183, Coarse D = 17686.3762
# Particle 720: Fine D = 7327.9698, Coarse D = 6629.7029
# Particle 721: Fine D = 15737.3673, Coarse D = 14943.6053
# Particle 722: Fine D = 20628.3745, Coarse D = 21066.2448
# Particle 723: Fine D = 5633.4879, Coarse D = 5233.4622
# Particle 724: Fine D = 32217.3169, Coarse D = 31859.2800
# Particle 725: Fine D = 5076.3770, Coarse D = 4405.6268
# Particle 726: Fine D = 7482.6580, Coarse D = 7156.0576
# Particle 727: Fine D = 2722.5738, Coarse D = 2198.5080
# Particle 728: Fine D = 29453.2207, Coarse D = 27197.9420
# Particle 729: Fine D = 13909.5197, Coarse D = 13710.7523
# Particle 730: Fine D = 2753.9269, Coarse D = 2001.9326
# Particle 731: Fine D = 3027.3653, Coarse D = 2766.8526
# Particle 732: Fine D = 13607.5585, Coarse D = 13935.6003
# Particle 733: Fine D = 8698.6054, Coarse D = 8272.6194
# Particle 734: Fine D = 15419.9915, Coarse D = 14026.7316
# Particle 735: Fine D = 4340.7554, Coarse D = 3656.9385
# Particle 736: Fine D = 11328.1122, Coarse D = 11420.7661
# Particle 737: Fine D = 18032.4315, Coarse D = 16000.5185
# Particle 738: Fine D = 19883.7163, Coarse D = 18701.9338
# Particle 739: Fine D = 7727.8616, Coarse D = 7934.7234
# Particle 740: Fine D = 5783.0068, Coarse D = 5332.1176
# Particle 741: Fine D = 1448.2061, Coarse D = 1223.5033
# Particle 742: Fine D = 36437.1588, Coarse D = 35636.2260
# Particle 743: Fine D = 18186.8690, Coarse D = 17434.9683
# Particle 744: Fine D = 11980.4782, Coarse D = 11387.8760
# Particle 745: Fine D = 4328.2365, Coarse D = 3850.5551
# Particle 746: Fine D = 18686.2670, Coarse D = 18270.8075
# Particle 747: Fine D = 24508.6812, Coarse D = 23504.3457
# Particle 748: Fine D = 8034.4287, Coarse D = 7749.8835
# Particle 749: Fine D = 4128.0026, Coarse D = 3602.6831
# Particle 750: Fine D = 11207.1271, Coarse D = 9290.5037
# Particle 751: Fine D = 4504.2814, Coarse D = 4550.0003
# Particle 752: Fine D = 28896.7011, Coarse D = 30164.6835
# Particle 753: Fine D = 7773.7870, Coarse D = 6958.0855
# Particle 754: Fine D = 2202.8697, Coarse D = 1613.8774
# Particle 755: Fine D = 11480.8385, Coarse D = 10354.7874
# Particle 756: Fine D = 10426.3223, Coarse D = 9822.4869
# Particle 757: Fine D = 10296.9552, Coarse D = 10347.6476
# Particle 758: Fine D = 26264.8801, Coarse D = 25391.3347
# Particle 759: Fine D = 16679.8422, Coarse D = 14822.8392
# Particle 760: Fine D = 8079.4310, Coarse D = 7305.2337
# Particle 761: Fine D = 30424.3359, Coarse D = 30275.9308
# Particle 762: Fine D = 1358.0287, Coarse D = 873.8471
# Particle 763: Fine D = 7991.4956, Coarse D = 8145.5182
# Particle 764: Fine D = 4514.7328, Coarse D = 4055.8160
# Particle 765: Fine D = 17405.5654, Coarse D = 16521.7056
# Particle 766: Fine D = 10139.4310, Coarse D = 10284.2663
# Particle 767: Fine D = 39268.2304, Coarse D = 37794.8299
# Particle 768: Fine D = 5795.1966, Coarse D = 5865.6836
# Particle 769: Fine D = 5248.5057, Coarse D = 4425.8928
# Particle 770: Fine D = 8597.4785, Coarse D = 8154.4263
# Particle 771: Fine D = 3325.8224, Coarse D = 2962.6855
# Particle 772: Fine D = 21411.7044, Coarse D = 20718.1717
# Particle 773: Fine D = 8164.5943, Coarse D = 7173.4557
# Particle 774: Fine D = 10244.0134, Coarse D = 10650.9178
# Particle 775: Fine D = 3677.8498, Coarse D = 3207.6268
# Particle 776: Fine D = 3271.5380, Coarse D = 2018.7976
# Particle 777: Fine D = 8076.0728, Coarse D = 7875.0591
# Particle 778: Fine D = 2677.6055, Coarse D = 2412.6877
# Particle 779: Fine D = 20725.7746, Coarse D = 21166.1590
# Particle 780: Fine D = 5916.7557, Coarse D = 5552.9252
# Particle 781: Fine D = 2972.2720, Coarse D = 1919.2368
# Particle 782: Fine D = 3929.4368, Coarse D = 3115.0832
# Particle 783: Fine D = 6872.1117, Coarse D = 6057.6113
# Particle 784: Fine D = 1705.5158, Coarse D = 1358.6047
# Particle 785: Fine D = 9241.7190, Coarse D = 8911.4090
# Particle 786: Fine D = 5399.0171, Coarse D = 4765.9141
# Particle 787: Fine D = 23957.6031, Coarse D = 21991.0556
# Particle 788: Fine D = 3023.4396, Coarse D = 2760.0252
# Particle 789: Fine D = 5410.6383, Coarse D = 4997.8893
# Particle 790: Fine D = 20903.2707, Coarse D = 19423.3114
# Particle 791: Fine D = 4363.7101, Coarse D = 3771.7081
# Particle 792: Fine D = 7836.9818, Coarse D = 7860.4439
# Particle 793: Fine D = 5759.4346, Coarse D = 5626.5297
# Particle 794: Fine D = 3155.9851, Coarse D = 2652.3036
# Particle 795: Fine D = 5528.4652, Coarse D = 5042.1365
# Particle 796: Fine D = 11247.6982, Coarse D = 10697.0650
# Particle 797: Fine D = 10287.6807, Coarse D = 10371.7715
# Particle 798: Fine D = 18878.3337, Coarse D = 18671.7124
# Particle 799: Fine D = 1577.0231, Coarse D = 1267.6265
# Particle 800: Fine D = 2201.8367, Coarse D = 2054.8746
# Particle 801: Fine D = 18800.0608, Coarse D = 18668.0837
# Particle 802: Fine D = 5052.0096, Coarse D = 3950.5036
# Particle 803: Fine D = 17063.0199, Coarse D = 16522.8268
# Particle 804: Fine D = 8795.2999, Coarse D = 7852.2867
# Particle 805: Fine D = 3240.1986, Coarse D = 2703.5006
# Particle 806: Fine D = 4587.9701, Coarse D = 3952.5248
# Particle 807: Fine D = 4511.1900, Coarse D = 4028.6322
# Particle 808: Fine D = 10629.6641, Coarse D = 8884.3390
# Particle 809: Fine D = 9118.6985, Coarse D = 8715.9686
# Particle 810: Fine D = 5950.9637, Coarse D = 5535.6891
# Particle 811: Fine D = 25951.7567, Coarse D = 24119.7154
# Particle 812: Fine D = 4572.6224, Coarse D = 4737.1661
# Particle 813: Fine D = 18455.9435, Coarse D = 16781.4700
# Particle 814: Fine D = 13974.4127, Coarse D = 12734.9847
# Particle 815: Fine D = 7752.7103, Coarse D = 6841.7618
# Particle 816: Fine D = 34317.3456, Coarse D = 34652.6170
# Particle 817: Fine D = 3692.3866, Coarse D = 3332.1640
# Particle 818: Fine D = 24554.9662, Coarse D = 21329.3486
# Particle 819: Fine D = 14052.8759, Coarse D = 14550.3975
# Particle 820: Fine D = 15202.9193, Coarse D = 15102.5056
# Particle 821: Fine D = 34541.1124, Coarse D = 34900.1739
# Particle 822: Fine D = 6256.5023, Coarse D = 6136.7716
# Particle 823: Fine D = 31862.4768, Coarse D = 28843.0753
# Particle 824: Fine D = 5031.9815, Coarse D = 4552.9531
# Particle 825: Fine D = 5128.8986, Coarse D = 4890.9299
# Particle 826: Fine D = 15721.6582, Coarse D = 15989.2919
# Particle 827: Fine D = 7010.4351, Coarse D = 6237.2423
# Particle 828: Fine D = 10604.1280, Coarse D = 9768.8742
# Particle 829: Fine D = 4366.3730, Coarse D = 4212.9231
# Particle 830: Fine D = 16786.5805, Coarse D = 15840.7706
# Particle 831: Fine D = 4954.7387, Coarse D = 4600.6010
# Particle 832: Fine D = 2619.3311, Coarse D = 2272.5763
# Particle 833: Fine D = 8952.2524, Coarse D = 8657.9937
# Particle 834: Fine D = 13966.0179, Coarse D = 14397.0354
# Particle 835: Fine D = 3001.7966, Coarse D = 2781.9355
# Particle 836: Fine D = 6213.5656, Coarse D = 5705.8011
# Particle 837: Fine D = 1584.3600, Coarse D = 1221.4847
# Particle 838: Fine D = 4098.1257, Coarse D = 3873.1040
# Particle 839: Fine D = 2902.1429, Coarse D = 2753.6712
# Particle 840: Fine D = 3492.1941, Coarse D = 2379.4886
# Particle 841: Fine D = 923.8505, Coarse D = 605.9957
# Particle 842: Fine D = 5827.3874, Coarse D = 5435.2639
# Particle 843: Fine D = 20251.8716, Coarse D = 18969.4910
# Particle 844: Fine D = 16866.2451, Coarse D = 15719.2048
# Particle 845: Fine D = 5656.6771, Coarse D = 5930.4070
# Particle 846: Fine D = 17319.6577, Coarse D = 16966.2625
# Particle 847: Fine D = 7173.1166, Coarse D = 6835.3939
# Particle 848: Fine D = 7217.6909, Coarse D = 6539.5100
# Particle 849: Fine D = 4050.5988, Coarse D = 4017.2059
# Particle 850: Fine D = 3220.4636, Coarse D = 2657.6377
# Particle 851: Fine D = 20278.7819, Coarse D = 19536.8940
# Particle 852: Fine D = 23513.6964, Coarse D = 22864.8206
# Particle 853: Fine D = 16309.4658, Coarse D = 15493.9602
# Particle 854: Fine D = 2100.9167, Coarse D = 2047.1912
# Particle 855: Fine D = 11896.0382, Coarse D = 11977.3407
# Particle 856: Fine D = 9520.6886, Coarse D = 8959.6298
# Particle 857: Fine D = 6884.6072, Coarse D = 6664.5220
# Particle 858: Fine D = 12515.2723, Coarse D = 11518.9243
# Particle 859: Fine D = 3174.6647, Coarse D = 2638.9029
# Particle 860: Fine D = 4532.5776, Coarse D = 4289.4358
# Particle 861: Fine D = 14881.9959, Coarse D = 14645.8075
# Particle 862: Fine D = 3489.2124, Coarse D = 3028.0010
# Particle 863: Fine D = 2775.9968, Coarse D = 2145.1858
# Particle 864: Fine D = 19828.5043, Coarse D = 19604.6853
# Particle 865: Fine D = 2464.4906, Coarse D = 2266.0416
# Particle 866: Fine D = 29118.7798, Coarse D = 29496.2721
# Particle 867: Fine D = 5634.7251, Coarse D = 4883.2158
# Particle 868: Fine D = 5141.4942, Coarse D = 4787.8838
# Particle 869: Fine D = 3901.1797, Coarse D = 3248.9180
# Particle 870: Fine D = 2826.3599, Coarse D = 2681.6115
# Particle 871: Fine D = 13479.4080, Coarse D = 13368.6561
# Particle 872: Fine D = 7851.5560, Coarse D = 7737.6696
# Particle 873: Fine D = 1900.6018, Coarse D = 1518.1930
# Particle 874: Fine D = 6254.8448, Coarse D = 6117.0522
# Particle 875: Fine D = 5232.9434, Coarse D = 4764.6697
# Particle 876: Fine D = 2171.4489, Coarse D = 1374.2018
# Particle 877: Fine D = 5780.8954, Coarse D = 5207.9747
# Particle 878: Fine D = 13080.7177, Coarse D = 11935.5971
# Particle 879: Fine D = 6220.2341, Coarse D = 5979.0469
# Particle 880: Fine D = 10036.0828, Coarse D = 9130.4719
# Particle 881: Fine D = 6872.9879, Coarse D = 7204.1321
# Particle 882: Fine D = 5335.1805, Coarse D = 4491.2343
# Particle 883: Fine D = 15605.6792, Coarse D = 13759.8319
# Particle 884: Fine D = 11217.3867, Coarse D = 11223.1914
# Particle 885: Fine D = 7496.6247, Coarse D = 7044.4869
# Particle 886: Fine D = 27171.9762, Coarse D = 24050.4970
# Particle 887: Fine D = 15445.3585, Coarse D = 15831.3802
# Particle 888: Fine D = 5060.4876, Coarse D = 4972.9275
# Particle 889: Fine D = 10066.3645, Coarse D = 9898.7951
# Particle 890: Fine D = 4673.4338, Coarse D = 4818.1372
# Particle 891: Fine D = 7300.8514, Coarse D = 5840.9754
# Particle 892: Fine D = 6704.7807, Coarse D = 7029.5727
# Particle 893: Fine D = 4621.5034, Coarse D = 4553.8363
# Particle 894: Fine D = 9844.7575, Coarse D = 8714.0589
# Particle 895: Fine D = 18965.4676, Coarse D = 18067.3287
# Particle 896: Fine D = 2237.4152, Coarse D = 1709.1440
# Particle 897: Fine D = 27073.0432, Coarse D = 25981.6266
# Particle 898: Fine D = 10143.9425, Coarse D = 9641.1156
# Particle 899: Fine D = 2469.8887, Coarse D = 2269.0597
# Particle 900: Fine D = 7962.0607, Coarse D = 7102.2524
# Particle 901: Fine D = 8005.7496, Coarse D = 7830.8111
# Particle 902: Fine D = 4184.0292, Coarse D = 3663.8765
# Particle 903: Fine D = 21231.5750, Coarse D = 21277.8296
# Particle 904: Fine D = 15411.4035, Coarse D = 15689.7776
# Particle 905: Fine D = 6582.2226, Coarse D = 6771.3678
# Particle 906: Fine D = 6049.4559, Coarse D = 5917.5251
# Particle 907: Fine D = 15358.8204, Coarse D = 14621.4537
# Particle 908: Fine D = 11895.3798, Coarse D = 10280.9301
# Particle 909: Fine D = 6992.4244, Coarse D = 6067.4451
# Particle 910: Fine D = 12132.7284, Coarse D = 12123.1828
# Particle 911: Fine D = 2929.5623, Coarse D = 2595.9953
# Particle 912: Fine D = 20709.6070, Coarse D = 20217.1045
# Particle 913: Fine D = 2059.8583, Coarse D = 1567.1375
# Particle 914: Fine D = 5152.3164, Coarse D = 4181.5478
# Particle 915: Fine D = 5087.1790, Coarse D = 4801.0735
# Particle 916: Fine D = 17715.0123, Coarse D = 16077.9858
# Particle 917: Fine D = 22894.5476, Coarse D = 20623.2314
# Particle 918: Fine D = 5736.1001, Coarse D = 5463.0414
# Particle 919: Fine D = 8186.8640, Coarse D = 8086.3040
# Particle 920: Fine D = 13200.3802, Coarse D = 12743.0635
# Particle 921: Fine D = 6108.4735, Coarse D = 6011.4976
# Particle 922: Fine D = 2464.2303, Coarse D = 2039.3890
# Particle 923: Fine D = 18897.5298, Coarse D = 19455.1785
# Particle 924: Fine D = 12689.7989, Coarse D = 12132.8445
# Particle 925: Fine D = 1698.9255, Coarse D = 1050.3153
# Particle 926: Fine D = 16597.5174, Coarse D = 15079.4032
# Particle 927: Fine D = 4119.6388, Coarse D = 3878.5287
# Particle 928: Fine D = 5318.5021, Coarse D = 4712.4609
# Particle 929: Fine D = 2467.3980, Coarse D = 1829.8841
# Particle 930: Fine D = 11875.5848, Coarse D = 11369.8723
# Particle 931: Fine D = 7261.4379, Coarse D = 6003.3545
# Particle 932: Fine D = 11606.7835, Coarse D = 10208.3694
# Particle 933: Fine D = 18851.0205, Coarse D = 18514.5137
# Particle 934: Fine D = 15910.1157, Coarse D = 16082.6638
# Particle 935: Fine D = 3571.9326, Coarse D = 3364.2853
# Particle 936: Fine D = 5710.0556, Coarse D = 5430.3738
# Particle 937: Fine D = 12283.3810, Coarse D = 11639.2406
# Particle 938: Fine D = 5409.1725, Coarse D = 5259.0662
# Particle 939: Fine D = 8203.5288, Coarse D = 7172.8316
# Particle 940: Fine D = 24021.6224, Coarse D = 23712.8600
# Particle 941: Fine D = 10844.3246, Coarse D = 9521.6704
# Particle 942: Fine D = 11277.9137, Coarse D = 10647.8844
# Particle 943: Fine D = 5478.9624, Coarse D = 5355.9450
# Particle 944: Fine D = 15150.8785, Coarse D = 14468.7468
# Particle 945: Fine D = 19078.2918, Coarse D = 18754.9033
# Particle 946: Fine D = 6963.2747, Coarse D = 6849.5548
# Particle 947: Fine D = 9240.5492, Coarse D = 9229.3562
# Particle 948: Fine D = 13487.3399, Coarse D = 12854.0924
# Particle 949: Fine D = 14150.2443, Coarse D = 14402.2529
# Particle 950: Fine D = 3405.5406, Coarse D = 3083.6960
# Particle 951: Fine D = 15398.0053, Coarse D = 14730.4672
# Particle 952: Fine D = 1252.7516, Coarse D = 994.5664
# Particle 953: Fine D = 45383.9558, Coarse D = 45890.7320
# Particle 954: Fine D = 10748.5121, Coarse D = 10690.6020
# Particle 955: Fine D = 23233.6731, Coarse D = 21766.0816
# Particle 956: Fine D = 19352.2756, Coarse D = 18898.3752
# Particle 957: Fine D = 5448.2372, Coarse D = 4682.1614
# Particle 958: Fine D = 3995.3756, Coarse D = 3820.0929
# Particle 959: Fine D = 5613.9741, Coarse D = 5297.0647
# Particle 960: Fine D = 1411.5081, Coarse D = 1116.5469
# Particle 961: Fine D = 9215.8245, Coarse D = 8150.0072
# Particle 962: Fine D = 5231.3214, Coarse D = 4207.0849
# Particle 963: Fine D = 19116.6980, Coarse D = 19156.3533
# Particle 964: Fine D = 5070.2181, Coarse D = 4167.2244
# Particle 965: Fine D = 3112.9645, Coarse D = 2215.4480
# Particle 966: Fine D = 3907.0205, Coarse D = 3445.5242
# Particle 967: Fine D = 10803.4411, Coarse D = 9983.4896
# Particle 968: Fine D = 17684.2002, Coarse D = 16757.2513
# Particle 969: Fine D = 5127.7988, Coarse D = 4571.2112
# Particle 970: Fine D = 3548.4984, Coarse D = 3138.6813
# Particle 971: Fine D = 3137.7639, Coarse D = 2895.4288
# Particle 972: Fine D = 16073.3369, Coarse D = 15392.6770
# Particle 973: Fine D = 5142.2373, Coarse D = 4739.7735
# Particle 974: Fine D = 9717.6485, Coarse D = 8098.3918
# Particle 975: Fine D = 3143.9793, Coarse D = 2790.2793
# Particle 976: Fine D = 8169.5504, Coarse D = 7240.6612
# Particle 977: Fine D = 19155.3527, Coarse D = 18935.8312
# Particle 978: Fine D = 1260.7659, Coarse D = 628.0638
# Particle 979: Fine D = 11795.7221, Coarse D = 11710.3378
# Particle 980: Fine D = 13247.8800, Coarse D = 13507.3804
# Particle 981: Fine D = 17400.1590, Coarse D = 16269.9271
# Particle 982: Fine D = 3925.7818, Coarse D = 3559.3862
# Particle 983: Fine D = 14181.9298, Coarse D = 13535.8615
# Particle 984: Fine D = 3988.4958, Coarse D = 3489.8359
# Particle 985: Fine D = 12431.6344, Coarse D = 11276.2351
# Particle 986: Fine D = 32360.3100, Coarse D = 31808.1829
# Particle 987: Fine D = 10871.6837, Coarse D = 9354.9857
# Particle 988: Fine D = 3472.4735, Coarse D = 3175.4073
# Particle 989: Fine D = 3098.8100, Coarse D = 2699.9010
# Particle 990: Fine D = 6191.3725, Coarse D = 5049.0155
# Particle 991: Fine D = 6366.4809, Coarse D = 5362.6594
# Particle 992: Fine D = 13736.6643, Coarse D = 13239.0517
# Particle 993: Fine D = 1014.2433, Coarse D = 516.2928
# Particle 994: Fine D = 3195.6971, Coarse D = 2968.0562
# Particle 995: Fine D = 22597.0607, Coarse D = 23189.2782
# Particle 996: Fine D = 15839.2585, Coarse D = 15060.4118
# Particle 997: Fine D = 11440.3360, Coarse D = 11968.1504
# Particle 998: Fine D = 2972.4340, Coarse D = 2622.2229
# Particle 999: Fine D = 8659.3132, Coarse D = 8310.8954

# %%
import matplotlib.pyplot as plt

def plot_MSDs(msd_fine, msd_coarse, time_range_fine, time_range_coarse, D_estimate_fine, D_estimate_coarse):
    plt.figure(figsize=(8, 6))
    plt.plot(time_range_fine, msd_fine, label=f'Fine MSD (D={D_estimate_fine:.3f})')
    plt.plot(time_range_coarse, msd_coarse, label=f'Coarse MSD (D={D_estimate_coarse:.3f})', marker='o')
    plt.xlabel('Time Lag (s)')
    plt.ylabel('MSD (nm^2)')
    plt.title('Mean Square Displacement Comparison')
    plt.legend()
    plt.grid(True)
    plt.show()

# Example for one particle
p = 997
trajectory = trajectories[p]
msd_full = mean_square_displacement(trajectory)
time_range_full = np.arange(nframes * nposframe) * dt / nposframe
D_estimate_fine = D_estimates_fine[p]

centroids = compute_centroid_positions(trajectory, nframes, nposframe)
msd_centroids = mean_square_displacement_from_centroids(centroids)
time_range_centroids = np.arange(nframes) * dt
D_estimate_coarse = D_estimates_coarse[p]

plot_MSDs(msd_full, msd_centroids, time_range_full, time_range_centroids, D_estimate_fine, D_estimate_coarse)
